# %% [markdown]
# # Homework 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name: Jun Luo
#
# Student ID: 792597
#
# Python version used: Python2.7

# %% [markdown]
# ## General info

# %% [markdown]
# <b>Due date</b>: 11pm, Sunday March 18th
#
# <b>Submission method</b>: see LMS
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -20% per day
#
# <b>Marks</b>: 5% of mark for class
#
# <b>Overview</b>: In this homework, you'll be using a corpus of tweets to do tokenisation of hashtags and build polarity classifers using bag of word (BOW) features.
#
# <b>Materials</b>: See the main class LMS page for information on the basic setup required for this class, including an iPython notebook viewer and the python packages NLTK, Numpy, Scipy, Matplotlib, Scikit-Learn, and Gensim. In particular, if you are not using a lab computer which already has it installed, we recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages (the packages listed above are all fine to use); if your iPython notebook doesn't run on the marker's machine, you will lose marks.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a few minutes, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). The amount each section is worth is given in parenthesis after the instructions. You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Extra credit</b>: Each homework has a task which is optional with respect to getting full marks on the assignment, but that can be used to offset any points lost on this or any other homework assignment (but not the final project or the exam). We recommend you skip over this step on your first pass, and come back if you have time: the amount of effort required to receive full marks (1 point) on an extra credit question will be substantially more than earning the same amount of credit on other parts of the homework.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via LMS. Minor changes and clarifications will be announced in the forum on LMS, we recommend you check the forum regularly.
#
# <b>Academic Misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place.

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# <b>Instructions</b>: For this homework we will be using the tweets in the <i>twitter_samples</i> corpus included with NLTK. You should start by accessing these tweets. Use the <i>strings</i> method included in the NLTK corpus reader for <i>twitter_samples</i> to access the tweets (as raw strings). Iterate over the full corpus, and print out the average length, in characters, of the tweets in the corpus. (0.5)

# %%
import nltk
import nltk.corpus
import numpy

corpus = nltk.corpus.twitter_samples.strings()
total_characters = 0
for tweet in corpus:
    total_characters += len(tweet)
print('Average Length:' + str(total_characters*1.0/len(corpus))+' characters')
# Out:
# Average Length:103.887266667 characters

# %% [markdown]
# <b>Instructions</b>: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. You should use a regular expression to extract all hashtags of length 8 or longer which consist only of lower case letters (other than the # at the beginning, of course, though this should be stripped off as part of the extraction process). Do <b>not</b> tokenise the entire tweet as part of this process. The hashtag might occur at the beginning or the end of the tweet; you should double-check that you aren't missing any. After you have collected them into a list, print out number of hashtags you have collected: for full credit, you must get the exact number that we expect.  (1.0)

# %%
"""
Daniel's post in the discussion board:

Assume the boundaries are whitespaces. So hashtags need to have whitespaces before and after 
(unless they occur in the beginning or the end of the tweet).
Cases like #thisperson's should not be captured. Yes, in real world we would probably like to capture this phenomenon as well. 
But to do this you need to assume some level of tokenisation already (splitting the 's) and you should not tokenise the tweet 
in that question (this is in the instructions).

"""

import re
hashtags = []
# Collect all the hashtags into an array
for tweet in corpus:
    array = re.findall(r"(?:^|(?<=\s))(?:#)([a-z]{8,})(?:$|(?=\s))", tweet)
    for hashtag in array:
        hashtags.append(hashtag)

print('Total Number of Hashtags:'+str(len(hashtags)))
# Out:
# Total Number of Hashtags:1411

# %% [markdown]
# <b>Instructions</b>: Now, tokenise the hashtags you've collected. To do this, you should implement a reversed version of the MaxMatch algorithm discussed in class (and in the reading), where matching begins at the end of the hashtag and progresses backwards. NLTK has a list of words that you can use for matching, see starter code below. Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatiser before matching. Note that the list of words is incomplete, and, if you are unable to make any longer match, your code should default to matching a single letter. Create a new list of tokenised hashtags (this should be a list of lists of strings) and use slicing to print out the last 20 hashtags in the list. (1.0)

# %%
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
def reverse_max_match(sentence, dictionary):
    if len(sentence)==0:
        return []
    for i in reversed(range(1,len(sentence)+1)):
        firstword = lemmatizer.lemmatize(sentence[-i:])
        remainder = sentence[:-i]
        if firstword in dictionary:
            return reverse_max_match(remainder,dictionary)+[firstword]
    # if no word was found, than make a one-character word
    firstword = lemmatizer.lemmatize(sentence[-1:])
    remainder = sentence[:-1]
    return reverse_max_match(remainder,dictionary)+[firstword]

words = nltk.corpus.words.words() # words is a Python list

# print(reverse_max_match('flowers',words))

# print(len(hashtags))
counter = 0
result2 = []
for hashtag in hashtags:
    counter+=1
#     if(counter%100 == 0):
#         print(counter)
    result2.append(reverse_max_match(hashtag,words))

print(result2[-20:])
# Out:
# [[u'leader', u'debate'], [u'wow', u'campaign'], [u'social', u'security'], [u'tory', u'lie'], [u'election'], [u'b', u'i', u'ase', u'd', u'b', u'b', u'c'], [u'labour', u'doorstep'], [u'b', u'i', u'ase', u'd', u'b', u'b', u'c'], [u'li', u'blab', u'con'], [u'b', u'b', u'c', u'debate'], [u'mi', u'li', u'fandom'], [u'u', u'k', u'parliament'], [u'bedroom', u'tax'], [u'disability'], [u'can', u'nab', u'is'], [u'vote', u'green'], [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting'], [u'bedroom', u'tax'], [u'disability'], [u'bankrupt']]

# %% [markdown]
# ### Extra Credit (Optional)
# <b>Instructions</b>: Implement the forward version of the MaxMatch algorithm as well, and print out all the hashtags which give different results for the two versions of MaxMatch. Your main task is to come up with a good way to select which of the two segmentations is better for any given case, and demonstrate that it works significantly better than using a single version of the algorithm for all hashtags. (1.0)

# %% [markdown]
# #### Answer:
#
# The method I use to select the better segmentation is Maximum Known Matching (MKM).(http://cs.uccs.edu/~jkalita/work/reu/REU2015/FinalPapers/05Reuter.pdf)
#
# The score is calculated using the formular below:
#
# $ Score(s) = \sqrt[i]{\sum_{k=1}^i len(w_{k})^2}$
#
# Where len(w) returns the length of a word w, and s is a segmentation into i words.
#
# The higher the score is, the better a segmentation is.
#
# It is obvious to see that max(score_a, score_b) >= score_a, max(score_a, score_b) >= score_b
#
# To illustrate whether it is significantly better, 2 scores are calculated:
# 1. improvement_forward: Sum of improvement of using two segmentations comparing to only using the forward max_match
# 2. improvement_reverse: Sum of improvement of using two segmentations comparing to only using the reverse max_match
#
# Then we will calculate the average improvement of score:
#
# average_improve_reverse = improve_reverse/(length of the corpus)
#
# average_improve_forward = improve_forward/(length of the corpus)
#
# The result below shows that choosing the the matching sequence with the highest score is better than using only one single mathching algorithm.
#
# ##### It gets about 6% improvement to using single reversed maxMatch, and 4% improvement comparing to using single forward maxMatch.
#
# The code below demonstrate the forward max_match algorithm and the score calculation process.

# %%
def max_match(sentence, dictionary):
    if len(sentence)==0:
        return []
    for i in reversed(range(1,len(sentence)+1)):
        firstword = lemmatizer.lemmatize(sentence[:i])
        remainder = sentence[i:]
        if firstword in dictionary:
            return [firstword]+max_match(remainder,dictionary)
    # if no word was found, than make a one-character word
    firstword = lemmatizer.lemmatize(sentence[:1])
    remainder = sentence[1:]
    return [firstword]+max_match(remainder,dictionary)

words = nltk.corpus.words.words() # words is a Python list
# print(words[:100])

# print(len(hashtags))
counter = 0
result = []
for hashtag in hashtags:
    counter+=1
#     if(counter%100 == 0):
#         print(counter)
    result.append(max_match(hashtag,words))
print(result)
# Out:
# [[u'at', u'ha', u'ba', u'ca'], [u'jasper', u'national', u'park'], [u'explore', u'albe', u'r', u'ta'], [u'snap', u'chat'], [u'snap', u'chat'], [u'k', u'i', u'k', u'horny'], [u'tag', u'for', u'like'], [u'bat', u'all', u'ade', u'lo', u's', u'gall', u'o'], [u'web', u'cam', u'ex'], [u'snap', u'chat'], [u'snap', u'chat', u'me'], [u'in', u'tag', u'ram'], [u'add', u'me', u'ons', u'nap', u'chat'], [u'k', u'i', u'k', u'ex', u'ting'], [u'orc', u'alo', u'v', u'e'], [u'snap', u'chat'], [u'horny', u'k', u'i', u'k'], [u'love', u'of', u'my', u'life'], [u'new', u'music'], [u'fresh', u'er', u'to', u'final'], [u'bug', u'bounty'], [u'undercover', u'bo', u's'], [u'za', u'yn', u'is', u'coming', u'back'], [u'k', u'i', u'k', u'ex', u'ting'], [u'hot', u'girl'], [u'new', u'beth', u'video'], [u'k', u'i', u'k', u'horny'], [u'tag', u'for', u'like'], [u'k', u'i', u'k', u'horny'], [u'g', u'i', u'ach', u'ie', u'tit', u'ti', u'wedding'], [u'i', u'gers', u'oft', u'he', u'day'], [u'summertime'], [u'shi', u'thouse'], [u'anyway', u'he', u'did', u'ani', u'ce', u'job'], [u'snap', u'chat'], [u'k', u'i', u'k', u'me', u'guy'], [u'snap', u'chat'], [u'nak', u'ama', u'forever'], [u'k', u'i', u'k', u'me', u'boy'], [u'hot', u'scratch'], [u'horny', u'k', u'i', u'k'], [u'best', u'oft', u'he', u'day'], [u'sab', u'ado', u'deg', u'ana', u'r', u'e', u'g', u'u', u'id', u'ore'], [u'feel', u'like', u'ani', u'di', u'o', u't'], [u'snap', u'chat'], [u'k', u'i', u'k', u'me', u'boy'], [u'we', u'love', u'you', u'nam', u'jo', u'on'], [u'weekend', u'of', u'madness'], [u'matter', u'oft', u'he', u'heart'], [u'snap', u'chat'], [u'snap', u'chat'], [u'like', u'for', u'like'], [u'hot', u'f', u'm', u'noa', u'id', u'i', u'l', u'forum', u'ria', u'na'], [u'horny', u'k', u'i', u'k'], [u'like', u'for', u'follow'], [u'han', u'nib', u'al'], [u'k', u'i', u'k', u'horny'], [u'snap', u'chat'], [u'add', u'me', u'ons', u'nap', u'chat'], [u'p', u're', u'mi', u'o', u'tum', u'undo'], [u'hot', u'spot', u'with', u'dan', u'r', u'is'], [u'find', u'd', u'j', u'dere', u'k'], [u'a', u'u', u'fail', u'i', u'a'], [u'k', u'i', u'k', u'me', u'guy'], [u'k', u'i', u'k', u'ex', u'ting'], [u'staff', u'or', u'd'], [u'snap', u'chat'], [u'k', u'i', u'k', u'me', u'boy'], [u'k', u'i', u'k', u'me', u'boy'], [u'we', u'want', u'ice', u'cream'], [u'roommate', u'experience'], [u'feel', u'good', u'f', u'rid', u'ay'], [u'p', u'hand', u'roid'], [u'snap', u'chat'], [u'country', u'music'], [u'sexy', u'sa', u'un', u'day'], [u'za', u'yn', u'is', u'coming', u'back'], [u'horny', u'k', u'i', u'k'], [u'k', u'i', u'k', u'men', u'ow'], [u'sab', u'ado', u'deg', u'ana', u'r', u'e', u'g', u'u', u'id', u'ore'], [u'determination'], [u'family', u'home'], [u'snap', u'chat'], [u'snap', u'chat', u'me'], [u'hot', u'girl'], [u'social', u'reward'], [u'cycler', u'evolution'], [u'snap', u'chat'], [u'horny', u'k', u'i', u'k'], [u'snap', u'chat'], [u'best', u'oft', u'he', u'day'], [u'good', u'music'], [u'hash', u'tag'], [u'snap', u'chat'], [u'k', u'i', u'k', u'horny'], [u'interracial'], [u'best', u'oft', u'he', u'day'], [u'good', u'music'], [u'sexy', u'sa', u'un', u'day'], [u'snap', u'chat'], [u'self', u'hot'], [u'disappointed'], [u'where', u'ist', u'he', u'un'], [u'summer', u'ism', u'i', u'ing'], [u'za', u'yn', u'is', u'coming', u'back'], [u'k', u'i', u'k', u'me', u'guy'], [u'k', u'i', u'k', u'men', u'ow'], [u'in', u'diem', u'u', u'i', u'c'], [u'self', u'hot'], [u'snap', u'chat'], [u'horny', u'k', u'i', u'k'], [u'elfin', u'de', u'l', u'mund', u'o'], [u'web', u'cam', u'ex'], [u'count', u'the', u'cost'], [u'my', u'brain', u'need', u'tosh', u'ut', u'off'], [u'death', u'by', u'bacon', u'mell'], [u'imi', u'n', u'toher'], [u'horny', u'k', u'i', u'k'], [u'photo', u'oft', u'he', u'day'], [u'like', u'for', u'like'], [u'in', u'diem', u'u', u'i', u'c'], [u'sexy', u'girl', u'by', u'precious', u'l', u'em', u'my'], [u'snap', u'chat'], [u'in', u'diem', u'u', u'i', u'c'], [u'snap', u'chat'], [u'in', u'diem', u'u', u'i', u'c'], [u'snap', u'chat'], [u'snap', u'chat', u'me'], [u'in', ...

# %%
for index,value in enumerate(result2):
#     print(result2[index])
    if not result2[index] == result[index]:
        print(result2[index])
        print(result[index])
        print('\r\n')
# Out:
# [u'a', u'th', u'aba', u'ca']
# [u'at', u'ha', u'ba', u'ca']
#
#
# [u'ex', u'p', u'loreal', u'ber', u'ta']
# [u'explore', u'albe', u'r', u'ta']
#
#
# [u'ba', u'tal', u'lad', u'el', u'o', u'gall', u'o']
# [u'bat', u'all', u'ade', u'lo', u's', u'gall', u'o']
#
#
# [u'web', u'cam', u'sex']
# [u'web', u'cam', u'ex']
#
#
# [u'in', u'ta', u'gram']
# [u'in', u'tag', u'ram']
#
#
# [u'add', u'm', u'eon', u'snap', u'chat']
# [u'add', u'me', u'ons', u'nap', u'chat']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'or', u'ca', u'love']
# [u'orc', u'alo', u'v', u'e']
#
#
# [u'f', u're', u'hers', u'to', u'final']
# [u'fresh', u'er', u'to', u'final']
#
#
# [u'under', u'c', u'o', u'verb', u'os']
# [u'undercover', u'bo', u's']
#
#
# [u'z', u'ay', u'ni', u'coming', u'back']
# [u'za', u'yn', u'is', u'coming', u'back']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'g', u'i', u'a', u'c', u'hie', u'tit', u'ti', u'wedding']
# [u'g', u'i', u'ach', u'ie', u'tit', u'ti', u'wedding']
#
#
# [u'i', u'gers', u'of', u'the', u'day']
# [u'i', u'gers', u'oft', u'he', u'day']
#
#
# [u'anyway', u'he', u'di', u'da', u'nice', u'job']
# [u'anyway', u'he', u'did', u'ani', u'ce', u'job']
#
#
# [u'be', u'stof', u'the', u'day']
# [u'best', u'oft', u'he', u'day']
#
#
# [u'sa', u'bad', u'ode', u'ga', u'nar', u'seg', u'u', u'id', u'ore']
# [u'sab', u'ado', u'deg', u'ana', u'r', u'e', u'g', u'u', u'id', u'ore']
#
#
# [u'feel', u'li', u'k', u'ean', u'idiot']
# [u'feel', u'like', u'ani', u'di', u'o', u't']
#
#
# [u'matter', u'of', u'the', u'heart']
# [u'matter', u'oft', u'he', u'heart']
#
#
# [u'hot', u'f', u'm', u'no', u'ai', u'di', u'l', u'for', u'ar', u'i', u'ana']
# [u'hot', u'f', u'm', u'noa', u'id', u'i', u'l', u'forum', u'ria', u'na']
#
#
# [u'han', u'ni', u'bal']
# [u'han', u'nib', u'al']
#
#
# [u'add', u'm', u'eon', u'snap', u'chat']
# [u'add', u'me', u'ons', u'nap', u'chat']
#
#
# [u'p', u'r', u'em', u'io', u'stum', u'undo']
# [u'p', u're', u'mi', u'o', u'tum', u'undo']
#
#
# [u'a', u'u', u'fa', u'ilium']
# [u'a', u'u', u'fail', u'i', u'a']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'st', u'afford']
# [u'staff', u'or', u'd']
#
#
# [u'we', u'wan', u'tice', u'cream']
# [u'we', u'want', u'ice', u'cream']
#
#
# [u'feel', u'good', u'f', u'r', u'i', u'day']
# [u'feel', u'good', u'f', u'rid', u'ay']
#
#
# [u'p', u'h', u'android']
# [u'p', u'hand', u'roid']
#
#
# [u'sexy', u'sa', u'sun', u'day']
# [u'sexy', u'sa', u'un', u'day']
#
#
# [u'z', u'ay', u'ni', u'coming', u'back']
# [u'za', u'yn', u'is', u'coming', u'back']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'sa', u'bad', u'ode', u'ga', u'nar', u'seg', u'u', u'id', u'ore']
# [u'sab', u'ado', u'deg', u'ana', u'r', u'e', u'g', u'u', u'id', u'ore']
#
#
# [u'cycle', u'revolution']
# [u'cycler', u'evolution']
#
#
# [u'be', u'stof', u'the', u'day']
# [u'best', u'oft', u'he', u'day']
#
#
# [u'be', u'stof', u'the', u'day']
# [u'best', u'oft', u'he', u'day']
#
#
# [u'sexy', u'sa', u'sun', u'day']
# [u'sexy', u'sa', u'un', u'day']
#
#
# [u'self', u'shot']
# [u'self', u'hot']
#
#
# [u'w', u'he', u'real', u'the', u'sun']
# [u'where', u'ist', u'he', u'un']
#
#
# [u'summer', u'is', u'missing']
# [u'summer', u'ism', u'i', u'ing']
#
#
# [u'z', u'ay', u'ni', u'coming', u'back']
# [u'za', u'yn', u'is', u'coming', u'back']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'self', u'shot']
# [u'self', u'hot']
#
#
# [u'el', u'find', u'elm', u'undo']
# [u'elfin', u'de', u'l', u'mund', u'o']
#
#
# [u'web', u'cam', u'sex']
# [u'web', u'cam', u'ex']
#
#
# [u'my', u'brain', u'need', u'to', u'shutoff']
# [u'my', u'brain', u'need', u'tosh', u'ut', u'off']
#
#
# [u'death', u'by', u'bacon', u'smell']
# [u'death', u'by', u'bacon', u'mell']
#
#
# [u'i', u'min', u'toher']
# [u'imi', u'n', u'toher']
#
#
# [u'photo', u'of', u'the', u'day']
# [u'photo', u'oft', u'he', u'day']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'han', u'ni', u'bal']
# [u'han', u'nib', u'al']
#
#
# [u'hot', u'f', u'm', u'no', u'ai', u'di', u'l', u'for', u'ar', u'i', u'ana']
# [u'hot', u'f', u'm', u'noa', u'id', u'i', u'l', u'forum', u'ria', u'na']
#
#
# [u'photo', u'of', u'the', u'day']
# [u'photo', u'oft', u'he', u'day']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'just', u'got', u'ka', u'ne', u'k', u'i', u'fie', u'd']
# [u'just', u'got', u'kan', u'e', u'k', u'if', u'ie', u'd']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'lo', u'u', u'i', u'si', u'ana']
# [u'lo', u'u', u'is', u'i', u'ana']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'do', u'copen', u'h', u'agen']
# [u'doc', u'open', u'hag', u'en']
#
#
# [u'phone', u'sex']
# [u'phone', u'ex']
#
#
# [u'k', u'i', u'k', u'k', u'om', u'ansa', u'bor']
# [u'k', u'i', u'k', u'ko', u'man', u'a', u'bor']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'web', u'cam', u'sex']
# [u'web', u'cam', u'ex']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'bra', u'si', u'lei', u'ra', u'o']
# [u'bra', u'i', u'lei', u'ra', u'o']
#
#
# [u'ba', u'tal', u'lad', u'el', u'o', u'gall', u'o']
# [u'bat', u'all', u'ade', u'lo', u's', u'gall', u'o']
#
#
# [u'give', u'cod', u'pie', u'c', u'ea', u'chance']
# [u'give', u'codpiece', u'ach', u'an', u'ce']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'han', u'ni', u'bal']
# [u'han', u'nib', u'al']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'hot', u'music', u'de', u'lo', u'c', u'o']
# [u'hot', u'music', u'de', u'loco', u's']
#
#
# [u't', u'he', u'trug', u'g', u'lei', u'real']
# [u'the', u'struggle', u'is', u'real']
#
#
# [u'b', u'b', u'logger']
# [u'b', u'blo', u'g', u'gers']
#
#
# [u'hot', u'music', u'de', u'lo', u'c', u'o']
# [u'hot', u'music', u'de', u'loco', u's']
#
#
# [u'web', u'cam', u'sex']
# [u'web', u'cam', u'ex']
#
#
# [u'p', u'r', u'em', u'io', u'stum', u'undo']
# [u'p', u're', u'mi', u'o', u'tum', u'undo']
#
#
# [u'she', u'skin', u'da', u'hot']
# [u'she', u'skin', u'dah', u'o', u't']
#
#
# [u'phone', u'sex']
# [u'phone', u'ex']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'bra', u'si', u'lei', u'ra', u'o']
# [u'bra', u'i', u'lei', u'ra', u'o']
#
#
# [u'v', u'i', u'erne', u'd', u'er', u'olena', u'hot']
# [u'vier', u'ne', u'de', u'role', u'na', u'hot']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'el', u'find', u'elm', u'undo']
# [u'elfin', u'de', u'l', u'mund', u'o']
#
#
# [u'sex', u'ta', u'ate', u'q', u'u', u'em', u'fi', u'm', u'seg', u'u', u'e', u'd', u'v', u'c', u'om', u'v', u'alen', u'ti', u'no']
# [u'sext', u'aa', u'te', u'q', u'u', u'em', u'fi', u'm', u'e', u'gue', u's', u'd', u'v', u'c', u'om', u'valent', u'in', u'o']
#
#
# [u'yo', u'g', u'yak', u'ar', u'ta']
# [u'yo', u'g', u'yak', u'art', u'a']
#
#
# [u'yo', u'g', u'yak', u'ar', u'ta']
# [u'yo', u'g', u'yak', u'art', u'a']
#
#
# [u'y', u'ay', u'they', u'look', u'great']
# [u'ya', u'y', u'they', u'look', u'great']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'my', u'pap', u'amy', u'pride']
# [u'my', u'papa', u'my', u'pride']
#
#
# [u'qua', u'c', u'ket', u'y', u'quack']
# [u'quack', u'e', u't', u'y', u'quack']
#
#
# [u'f', u'ah', u'r', u'in', u'ah', u'mad']
# [u'fa', u'h', u'r', u'in', u'ah', u'mad']
#
#
# [u'teng', u'k', u'u', u'a', u'ar', u'on', u'shah']
# [u'teng', u'k', u'u', u'aa', u'r', u'ons', u'hah']
#
#
# [u'ha', u'v', u'ea', u'good', u'day']
# [u'have', u'ago', u'odd', u'ay']
#
#
# [u'super', u'smash']
# [u'super', u'mash']
#
#
# [u'hot', u'n', u'sexy']
# [u'hot', u'n', u'ex', u'y']
#
#
# [u'frisky', u'f', u'r', u'i', u'day']
# [u'frisky', u'f', u'rid', u'ay']
#
#
# [u'dis', u'n', u'ey', u'infinity']
# [u'dis', u'ne', u'yin', u'finity']
#
#
# [u'p', u'e', u'na', u'c', u'ovum']
# [u'pen', u'a', u'c', u'ovum']
#
#
# [u'la', u'tinhouse']
# [u'lat', u'n', u'house']
#
#
# [u'photo', u'of', u'the', u'day']
# [u'photo', u'oft', u'he', u'day']
#
#
# [u'she', u'skin', u'da', u'hot']
# [u'she', u'skin', u'dah', u'o', u't']
#
#
# [u'f', u'o', u'ie', u'g', u'ra']
# [u'f', u'o', u'ie', u'gra', u's']
#
#
# [u'che', u'c', u'king']
# [u'check', u'ing']
#
#
# [u'j', u'our', u'no', u'request']
# [u'jo', u'urn', u'ore', u'quest']
#
#
# [u'g', u'otto', u'love', u'bank']
# [u'got', u'tol', u'o', u'v', u'e', u'bank']
#
#
# [u'qua', u'c', u'ket', u'y', u'quack']
# [u'quack', u'e', u't', u'y', u'quack']
#
#
# [u'top', u'travel', u'c', u'en', u'tar']
# [u'top', u'travel', u'cent', u'ar']
#
#
# [u'l', u'b', u'logger']
# [u'l', u'blo', u'g', u'gers']
#
#
# [u'p', u'b', u'logger']
# [u'p', u'blo', u'g', u'gers']
#
#
# [u'de', u'di', u'ca', u'ted', u'fan']
# [u'dedicate', u'd', u'fan']
#
#
# [u'add', u'm', u'eon', u'b', u'b', u'm']
# [u'add', u'me', u'on', u'b', u'b', u'm']
#
#
# [u'scot', u'lan', u'dis', u'massive']
# [u'scot', u'land', u'ism', u'assi', u'v', u'e']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'k', u'i', u'k', u'k', u'om', u'ansa', u'bor']
# [u'k', u'i', u'k', u'ko', u'man', u'a', u'bor']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'take', u'one', u'to', u'k', u'no', u'wone']
# [u'take', u'one', u'to', u'know', u'one']
#
#
# [u'b', u'eme', u'code']
# [u'be', u'me', u'code']
#
#
# [u'p', u'roud', u'to', u'b', u'eme']
# [u'pro', u'u', u'd', u'tobe', u'me']
#
#
# [u'el', u'find', u'elm', u'undo']
# [u'elfin', u'de', u'l', u'mund', u'o']
#
#
# [u'trace', u'request']
# [u'tracer', u'e', u'quest']
#
#
# [u'sa', u'bad', u'ode', u'ga', u'nar', u'seg', u'u', u'id', u'ore']
# [u'sab', u'ado', u'deg', u'ana', u'r', u'e', u'g', u'u', u'id', u'ore']
#
#
# [u'sexy', u'sa', u'sun', u'day']
# [u'sexy', u'sa', u'un', u'day']
#
#
# [u'qua', u'c', u'ket', u'y', u'quack']
# [u'quack', u'e', u't', u'y', u'quack']
#
#
# [u'han', u'ni', u'bal']
# [u'han', u'nib', u'al']
#
#
# [u'phone', u'sex']
# [u'phone', u'ex']
#
#
# [u'crowd', u'fun', u'ding']
# [u'crowd', u'fundus', u'n', u'g']
#
#
# [u'f', u'r', u'i', u'day', u'fun']
# [u'f', u'rid', u'ay', u'fun']
#
#
# [u'e', u'jay', u'st', u'er']
# [u'e', u'jay', u'te', u'r']
#
#
# [u'word', u'of', u'the', u'week']
# [u'word', u'oft', u'hew', u'e', u'e', u'k']
#
#
# [u'free', u'b', u'ie', u'f', u'r', u'i', u'day']
# [u'free', u'b', u'ie', u'f', u'rid', u'ay']
#
#
# [u'i', u'need', u'feminism', u'because']
# [u'in', u'e', u'e', u'd', u'feminism', u'because']
#
#
# [u'r', u'u', u'drama', u'dev', u'i']
# [u'rud', u'ram', u'ade', u'v', u'i']
#
#
# [u'b', u'randing']
# [u'brand', u'ing']
#
#
# [u'love', u'summertime']
# [u'love', u'um', u'me', u'r', u'time']
#
#
# [u'tele', u'c', u'o', u'm']
# [u'tele', u'c', u'om', u's']
#
#
# [u'f', u'r', u'i', u'day', u'feeling']
# [u'f', u'rid', u'ay', u'feeling']
#
#
# [u'f', u'o', u'ie', u'g', u'ra']
# [u'f', u'o', u'ie', u'gra', u's']
#
#
# [u'f', u'avo', u'u', u'rite']
# [u'fa', u'v', u'our', u'it', u'e']
#
#
# [u'tele', u'c', u'o', u'm']
# [u'tele', u'c', u'om', u's']
#
#
# [u're', u'alo', u'shi']
# [u'real', u'o', u'hi']
#
#
# [u'deal', u'ut', u'hao', u'note', u'ba', u'chao']
# [u'deal', u'ut', u'hao', u'note', u'bach', u'a', u'o']
#
#
# [u'binding', u'of', u'is', u'sac']
# [u'binding', u'of', u'i', u'a', u'c']
#
#
# [u'hot', u'music', u'de', u'lo', u'c', u'o']
# [u'hot', u'music', u'de', u'loco', u's']
#
#
# [u'super', u'hero']
# [u'superhero', u'e']
#
#
# [u's', u'c', u'i', u'fi', u'fan']
# [u's', u'c', u'if', u'if', u'an']
#
#
# [u'li', u'v', u'eon', u'st', u'rea', u'mate']
# [u'live', u'ons', u't', u'ream', u'ate']
#
#
# [u'bowwow', u'chi', u'ca', u'wow', u'wow']
# [u'bowwow', u'chic', u'aw', u'ow', u'wow']
#
#
# [u'qua', u'c', u'ket', u'y', u'quack']
# [u'quack', u'e', u't', u'y', u'quack']
#
#
# [u'it', u'sa', u'marvel', u'thing']
# [u'it', u'amar', u'v', u'elt', u'hing']
#
#
# [u'the', u'g', u'ran', u'dad']
# [u'the', u'grand', u'ad']
#
#
# [u'f', u'r', u'i', u'day', u'feeling']
# [u'f', u'rid', u'ay', u'feeling']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'sunn', u'yday']
# [u'sunny', u'day']
#
#
# [u'qua', u'c', u'ket', u'y', u'quack']
# [u'quack', u'e', u't', u'y', u'quack']
#
#
# [u'v', u'c', u'o', u'good']
# [u'v', u'cog', u'o', u'od']
#
#
# [u'v', u'c', u'o', u'phi', u'l']
# [u'v', u'cop', u'hi', u'l']
#
#
# [u'v', u'c', u'o', u'cousin']
# [u'v', u'coco', u'u', u'in']
#
#
# [u'horse', u'racing']
# [u'horser', u'a', u'c', u'ing']
#
#
# [u'horse', u'racing', u'tip']
# [u'horser', u'a', u'c', u'ing', u'tip']
#
#
# [u'p', u'r', u'em', u'io', u'stum', u'undo']
# [u'p', u're', u'mi', u'o', u'tum', u'undo']
#
#
# [u'k', u'i', u'k', u'k', u'om', u'ansa', u'bor']
# [u'k', u'i', u'k', u'ko', u'man', u'a', u'bor']
#
#
# [u'photo', u'of', u'the', u'day']
# [u'photo', u'oft', u'he', u'day']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'k', u'e', u'e', u'pit', u'local']
# [u'keep', u'it', u'local']
#
#
# [u'k', u'e', u'e', u'pit', u'local']
# [u'keep', u'it', u'local']
#
#
# [u'qua', u'c', u'ket', u'y', u'quack']
# [u'quack', u'e', u't', u'y', u'quack']
#
#
# [u'in', u'ta', u'good']
# [u'in', u'tag', u'o', u'od']
#
#
# [u'photo', u'of', u'the', u'day']
# [u'photo', u'oft', u'he', u'day']
#
#
# [u'video', u'g', u'rap', u'her']
# [u'video', u'graph', u'er']
#
#
# [u'pro', u'sec', u'c', u'o']
# [u'prose', u'c', u'c', u'o']
#
#
# [u'de', u'c', u'o', u'rating']
# [u'de', u'cora', u'ting']
#
#
# [u's', u'love', u'ni', u'a']
# [u'sloven', u'i', u'a']
#
#
# [u't', u'el', u'lan', u'old', u'joke', u'day']
# [u'tell', u'an', u'old', u'joke', u'day']
#
#
# [u'be', u'stof', u'the', u'day']
# [u'best', u'oft', u'he', u'day']
#
#
# [u'p', u'r', u'em', u'io', u'stum', u'undo']
# [u'p', u're', u'mi', u'o', u'tum', u'undo']
#
#
# [u'yo', u'g', u'yak', u'ar', u'ta']
# [u'yo', u'g', u'yak', u'art', u'a']
#
#
# [u'w', u'alan', u'g', u'ma', u'kaka', u'pig', u'i', u'l', u'akin']
# [u'wa', u'lan', u'g', u'ma', u'kaka', u'pig', u'i', u'l', u'akin']
#
#
# [u'healthy', u'life', u'style']
# [u'healthy', u'life', u't', u'y', u'l', u'e']
#
#
# [u'non', u'scrip', u'ted']
# [u'non', u'script', u'e', u'd']
#
#
# [u'add', u'm', u'eon', u'snap', u'chat']
# [u'add', u'me', u'ons', u'nap', u'chat']
#
#
# [u'k', u'i', u'k', u'm', u'enow']
# [u'k', u'i', u'k', u'men', u'ow']
#
#
# [u'sexy', u'sa', u'tur', u'day']
# [u'sexy', u'sat', u'urd', u'ay']
#
#
# [u'k', u'i', u'k', u'sex', u'ting']
# [u'k', u'i', u'k', u'ex', u'ting']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'extreme', u'sport']
# [u'extreme', u'port']
#
#
# [u'b', u'logger', u're', u'q', u'u', u'i', u'red']
# [u'blo', u'g', u'gers', u'require', u'd']
#
#
# [u'b', u'logger', u'swan', u'ted']
# [u'blo', u'g', u'gers', u'want', u'e', u'd']
#
#
# [u'a', u'shram', u'calling']
# [u'ash', u'ram', u'calling']
#
#
# [u'ni', u'te', u'flirt']
# [u'nit', u'e', u'flirt']
#
#
# [u'n', u'om', u'n', u'om', u'n', u'om']
# [u'no', u'm', u'no', u'm', u'no', u'm']
#
#
# [u'w', u'upper', u'tal']
# [u'wup', u'pert', u'al']
#
#
# [u'in', u'ta', u'good']
# [u'in', u'tag', u'o', u'od']
#
#
# [u'sexy', u'sa', u'sun', u'day']
# [u'sexy', u'sa', u'un', u'day']
#
#
# [u'in', u'die', u'music']
# [u'in', u'diem', u'u', u'i', u'c']
#
#
# [u'frisky', u'fi', u'day']
# [u'frisky', u'fid', u'ay']
#
#
# [u'qua', u'c', u'ket', u'y', u'quack']
# [u'quack', u'e', u't', u'y', u'quack']
#
#
# [u'messenger', u'for', u'aday']
# [u'messenger', u'forum', u'day']
#
#
# [u'sin', u'ga', u'pore']
# [u'sing', u'a', u'pore']
#
#
# [u'you', u'rewelcome']
# [u'your', u'ewe', u'l', u'come']
#
#
# [u'hind', u'u', u'god']
# [u'hind', u'ug', u'od']
#
#
# [u'm', u'elb', u'our', u'ne', u'bur', u'gers']
# [u'mel', u'bourn', u'e', u'burg', u'er']
#
#
# [u'l', u'on', u'do', u'u', u'trading']
# [u'lo', u'n', u'dout', u'rad', u'ing']
#
#
# [u'in', u'ta', u'gram']
# [u'in', u'tag', u'ram']
#
#
# [u'mar', u'i', u'ti', u'm', u'enation']
# [u'maritime', u'nation']
#
#
# [u'the', u'world', u'would', u'change']
# [u'thew', u'or', u'l', u'd', u'would', u'change']
#
#
# [u'z', u'or', u'r', u'ore', u'tur', u'm']
# [u'zorro', u'ret', u'ur', u'm']
#
#
# [u'h', u'u', u'ga', u'husky']
# [u'hug', u'ahu', u'sky']
#
#
# [u'd', u'avid', u'cam', u'er', u'on', u'tweet']
# [u'da', u'v', u'id', u'came', u'r', u'on', u'tweet']
#
#
# [u'great', u'storm']
# [u'great', u'tor', u'm']
#
#
# [u'al', u'ex', u'almond']
# [u'ale', u'x', u'almond']
#
#
# [u'scot', u'ti', u'sh', u'labour']
# [u'scot', u'ti', u'h', u'labour']
#
#
# [u'mi', u'li', u'stumble']
# [u'mil', u'ist', u'umble']
#
#
# [u'rude', u'man', u'slap', u'down']
# [u'rude', u'man', u'lap', u'down']
#
#
# [u'al', u'li', u'nit', u'together']
# [u'all', u'in', u'it', u'together']
#
#
# [u'mil', u'li', u'brand', u'cut']
# [u'mill', u'i', u'brand', u'cut']
#
#
# [u'an', u'tag', u'had', u'h']
# [u'anta', u'g', u'had', u'h']
#
#
# [u'mil', u'li', u'brand', u'cut']
# [u'mill', u'i', u'brand', u'cut']
#
#
# [u'vote', u'labour', u'or', u'else']
# [u'vote', u'labour', u'ore', u'l', u'e']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']
#
#
# [u'ask', u'ni', u'cola', u'sturgeon']
# [u'ask', u'ni', u'cola', u'tur', u'geo', u'n']
#
#
# [u'e', u'd', u'mi', u'li', u'band']
# [u'e', u'd', u'mil', u'iba', u'n', u'd']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'grant', u'shap', u'p']
# [u'grant', u'hap', u'p']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'say', u'si', u'tall']
# [u'say', u'it', u'all']
#
#
# [u'cant', u'be', u'arse', u'd', u'm', u'p']
# [u'cant', u'bear', u'e', u'd', u'm', u'p']
#
#
# [u'e', u'd', u'mi', u'li', u'band']
# [u'e', u'd', u'mil', u'iba', u'n', u'd']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'mil', u'li', u'band']
# [u'mill', u'iba', u'n', u'd']
#
#
# [u'mi', u'li', u'madness']
# [u'mil', u'i', u'madness']
#
#
# [u'to', u'wa', u'kana']
# [u'tow', u'aka', u'na']
#
#
# [u'mi', u'li', u'madness']
# [u'mil', u'i', u'madness']
#
#
# [u'scot', u'ti', u'sh', u'labour']
# [u'scot', u'ti', u'h', u'labour']
#
#
# [u'l', u'even', u'son']
# [u'lev', u'en', u'on']
#
#
# [u'mi', u'li', u'brand', u'cut']
# [u'mil', u'i', u'brand', u'cut']
#
#
# [u'we', u'are', u'all', u'do', u'o', u'me', u'd']
# [u'wear', u'ea', u'l', u'l', u'doom', u'e', u'd']
#
#
# [u'mi', u'li', u'brand', u'cut']
# [u'mil', u'i', u'brand', u'cut']
#
#
# [u'fa', u'rage', u'i', u'cal']
# [u'far', u'age', u'i', u'cal']
#
#
# [u'al', u'ex', u'almond']
# [u'ale', u'x', u'almond']
#
#
# [u'do', u'u', u'blee', u'ur', u'o', u'pean', u'trouble']
# [u'double', u'eu', u'rope', u'ant', u'roub', u'l', u'e']
#
#
# [u'mi', u'li', u'brand', u'cut']
# [u'mil', u'i', u'brand', u'cut']
#
#
# [u'mil', u'li', u'brand']
# [u'mill', u'i', u'brand']
#
#
# [u'li', u'b', u'd', u'em', u'problem']
# [u'li', u'b', u'de', u'm', u'problem']
#
#
# [u'al', u'ex', u'almond']
# [u'ale', u'x', u'almond']
#
#
# [u'mil', u'li', u'brand', u'cut']
# [u'mill', u'i', u'brand', u'cut']
#
#
# [u'al', u'ex', u'almond']
# [u'ale', u'x', u'almond']
#
#
# [u'horse', u'ha', u'bo', u'l', u'ted']
# [u'horse', u'ha', u'bolt', u'e', u'd']
#
#
# [u'mi', u'li', u'madness']
# [u'mil', u'i', u'madness']
#
#
# [u'mi', u'li', u'brand']
# [u'mil', u'i', u'brand']
#
#
# [u'mil', u'li', u'brand', u'cut']
# [u'mill', u'i', u'brand', u'cut']
#
#
# [u'li', u'b', u'd', u'em', u'problem']
# [u'li', u'b', u'de', u'm', u'problem']
#
#
# [u'm', u'p', u'ona', u'train']
# [u'm', u'pon', u'at', u'rain']
#
#
# [u'mil', u'li', u'brand', u'cut']
# [u'mill', u'i', u'brand', u'cut']
#
#
# [u'we', u'are', u'all', u'do', u'o', u'me', u'd']
# [u'wear', u'ea', u'l', u'l', u'doom', u'e', u'd']
#
#
# [u'nick', u'robin', u'son']
# [u'nick', u'robin', u'on']
#
#
# [u'rule', u'b', u'r', u'i', u'tan', u'ni', u'a']
# [u'rule', u'brit', u'ann', u'i', u'a']
#
#
# [u'welcome', u'toe', u'sex']
# [u'welcome', u'toe', u'ex']
#
#
# [u'bairn', u'snot', u'bomb']
# [u'bairn', u'not', u'bomb']
#
#
# [u'we', u'are', u'all', u'do', u'o', u'me', u'd']
# [u'wear', u'ea', u'l', u'l', u'doom', u'e', u'd']
#
#
# [u'ca', u'mero', u'net', u'te']
# [u'came', u'rone', u't', u'te']
#
#
# [u'we', u'are', u'all', u'do', u'o', u'me', u'd']
# [u'wear', u'ea', u'l', u'l', u'doom', u'e', u'd']
#
#
# [u'nick', u'robin', u'son']
# [u'nick', u'robin', u'on']
#
#
# [u'mi', u'li', u'brand', u'cut']
# [u'mil', u'i', u'brand', u'cut']
#
#
# [u'al', u'ex', u'almond']
# [u'ale', u'x', u'almond']
#
#
# [u'cat', u'chin', u'gup']
# [u'catching', u'up']
#
#
# [u'handled', u'that', u'ba', u'hing', u'well']
# [u'handled', u'that', u'bash', u'ing', u'well']
#
#
# [u'nick', u'robin', u'son']
# [u'nick', u'robin', u'on']
#
#
# [u'mil', u'li', u'brand', u'cut']
# [u'mill', u'i', u'brand', u'cut']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u're', u'tweet', u'and', u'follow', u'me']
# [u'ret', u'weet', u'and', u'follow', u'me']
#
#
# [u'bairn', u'snot', u'bomb']
# [u'bairn', u'not', u'bomb']
#
#
# [u'mi', u'li', u'brand', u'cut']
# [u'mil', u'i', u'brand', u'cut']
#
#
# [u'j', u'u', u't', u'ayin']
# [u'just', u'say', u'in']
#
#
# [u'al', u'ex', u'almond']
# [u'ale', u'x', u'almond']
#
#
# [u'immigrant', u'solution']
# [u'immigrant', u'o', u'lut', u'ion']
#
#
# [u's', u'cotland']
# [u'scot', u'land']
#
#
# [u'star', u'tup']
# [u'start', u'up', u's']
#
#
# [u'ask', u'fa', u'rage']
# [u'ask', u'far', u'age']
#
#
# [u'ask', u'for', u'money']
# [u'ask', u'form', u'one', u'y']
#
#
# [u'li', u'b', u'd', u'em', u'problem']
# [u'li', u'b', u'de', u'm', u'problem']
#
#
# [u'm', u'p', u'ona', u'train']
# [u'm', u'pon', u'at', u'rain']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']
#
#
# [u'vote', u'n', u'p', u'get', u'sexy']
# [u'vote', u'n', u'p', u'get', u'ex', u'y']
#
#
# [u'j', u'u', u't', u'ayin']
# [u'just', u'say', u'in']
#
#
# [u'hyp', u'no', u'toad']
# [u'hyp', u'not', u'o', u'ad']
#
#
# [u'hyp', u'no', u'toad']
# [u'hyp', u'not', u'o', u'ad']
#
#
# [u'p', u'ae', u'dob', u'r', u'i', u'tain']
# [u'pa', u'e', u'dob', u'rita', u'in']
#
#
# [u'p', u'ae', u'dob', u'r', u'i', u'tain']
# [u'pa', u'e', u'dob', u'rita', u'in']
#
#
# [u'p', u'ae', u'dob', u'r', u'i', u'tain']
# [u'pa', u'e', u'dob', u'rita', u'in']
#
#
# [u'p', u'ae', u'dob', u'r', u'i', u'tain']
# [u'pa', u'e', u'dob', u'rita', u'in']
#
#
# [u'scot', u'ti', u'sh', u'labour']
# [u'scot', u'ti', u'h', u'labour']
#
#
# [u'mil', u'li', u'brand', u'cut']
# [u'mill', u'i', u'brand', u'cut']
#
#
# [u'dont', u'v', u'o', u't', u'eu', u'kip']
# [u'dont', u'vote', u'u', u'kip']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'no', u'idea', u'wha', u'ti', u'm', u'doing']
# [u'no', u'idea', u'what', u'i', u'm', u'doing']
#
#
# [u'h', u'ar', u'de', u'st', u'challenge']
# [u'hard', u'e', u'tch', u'all', u'en', u'ge']
#
#
# [u'might', u'of', u'gotten', u'cham', u'pan', u'ge']
# [u'might', u'of', u'gotten', u'champ', u'an', u'ge']
#
#
# [u'messe', u'swith', u'my', u'head']
# [u'mess', u'with', u'my', u'head']
#
#
# [u'li', u'b', u'd', u'em', u'problem']
# [u'li', u'b', u'de', u'm', u'problem']
#
#
# [u'nick', u'c', u'l', u'egg']
# [u'nick', u'cleg', u'g']
#
#
# [u'c', u'l', u'u', u'el', u'es']
# [u'clue', u'l', u'es']
#
#
# [u'i', u'sit', u'right']
# [u'is', u'it', u'right']
#
#
# [u'la', u'nar', u'khu', u'sting']
# [u'lan', u'ark', u'husting', u's']
#
#
# [u'working', u'c', u'la', u'story']
# [u'working', u'class', u'tory']
#
#
# [u'li', u'b', u'd', u'em', u'problem']
# [u'li', u'b', u'de', u'm', u'problem']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']
#
#
# [u'rule', u'b', u'r', u'i', u'tan', u'ni', u'a']
# [u'rule', u'brit', u'ann', u'i', u'a']
#
#
# [u'use', u'your', u'sense']
# [u'use', u'yours', u'ense']
#
#
# [u'n', u'erd', u'lover']
# [u'ne', u'r', u'd', u'lover']
#
#
# [u'la', u'nar', u'khu', u'sting']
# [u'lan', u'ark', u'husting', u's']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'ask', u'fa', u'rage']
# [u'ask', u'far', u'age']
#
#
# [u'v', u'o', u't', u'eu', u'kip']
# [u'vote', u'u', u'kip']
#
#
# [u'you', u'reap', u'what', u'you', u'sow']
# [u'your', u'ea', u'p', u'what', u'you', u'sow']
#
#
# [u'cloud', u'coo', u'ko', u'o']
# [u'cloud', u'cook', u'o', u'o']
#
#
# [u'badger', u'scull', u'tory']
# [u'badger', u'cull', u'tory']
#
#
# [u'bairn', u'snot', u'bomb']
# [u'bairn', u'not', u'bomb']
#
#
# [u'wear', u'eon', u'the', u'same', u'side', u'get', u'rid', u'of', u'cam', u'er', u'on']
# [u'wear', u'eon', u'the', u'same', u'ide', u'get', u'rid', u'of', u'came', u'r', u'on']
#
#
# [u'ask', u'fa', u'rage']
# [u'ask', u'far', u'age']
#
#
# [u'f', u'rust', u'rated']
# [u'frustrate', u'd']
#
#
# [u'or', u'g', u'anise', u'd', u'crime']
# [u'organ', u'is', u'e', u'd', u'crime']
#
#
# [u'b', u'b', u'c', u'election']
# [u'b', u'b', u'ce', u'lection']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']
#
#
# [u'fa', u'rage', u'fail']
# [u'far', u'age', u'fail']
#
#
# [u'v', u'o', u't', u'eu', u'kip']
# [u'vote', u'u', u'kip']
#
#
# [u'ask', u'fa', u'rage']
# [u'ask', u'far', u'age']
#
#
# [u's', u'tur', u'war']
# [u'st', u'ur', u'war']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'blue', u'tinted', u'spec']
# [u'bluet', u'in', u'ted', u'p', u'e', u'c']
#
#
# [u'stum', u'b', u'legate']
# [u'stumble', u'gate']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']
#
#
# [u'ask', u'ni', u'cola', u'sturgeon']
# [u'ask', u'ni', u'cola', u'tur', u'geo', u'n']
#
#
# [u'fa', u'rage', u'fail']
# [u'far', u'age', u'fail']
#
#
# [u'wat', u'k', u'ie', u'st', u'n', u'l']
# [u'wat', u'k', u'y', u't', u'n', u'l']
#
#
# [u'scot', u'ti', u'sh', u'labour']
# [u'scot', u'ti', u'h', u'labour']
#
#
# [u'ask', u'fa', u'rage']
# [u'ask', u'far', u'age']
#
#
# [u'to', u'rie', u'manifesto']
# [u'torus', u'em', u'ani', u'fest', u'o']
#
#
# [u'ow', u'ne', u'd', u'by', u'the', u'northerner']
# [u'own', u'e', u'd', u'byth', u'en', u'ort', u'herne', u'r']
#
#
# [u'ask', u'ni', u'gel', u'far', u'ge']
# [u'ask', u'nig', u'elf', u'ar', u'ge']
#
#
# [u'man', u'chester']
# [u'manche', u'st', u'er']
#
#
# [u'i', u'm', u'mig', u'ratio', u'nu', u'k']
# [u'immigration', u'u', u'k']
#
#
# [u'green', u'surge']
# [u'green', u'urge']
#
#
# [u'v', u'o', u't', u'eu', u'kip']
# [u'vote', u'u', u'kip']
#
#
# [u'get', u'to', u'the', u'point']
# [u'get', u'tot', u'hep', u'oint']
#
#
# [u'h', u'or', u'rib', u'leman']
# [u'horrible', u'man']
#
#
# [u'h', u'or', u'rib', u'leman']
# [u'horrible', u'man']
#
#
# [u'ask', u'ni', u'gel']
# [u'ask', u'nig', u'el']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'h', u'or', u'rib', u'leman']
# [u'horrible', u'man']
#
#
# [u'mil', u'li', u'band']
# [u'mill', u'iba', u'n', u'd']
#
#
# [u'hyp', u'ocracy']
# [u'hypo', u'c', u'racy']
#
#
# [u'li', u'b', u'd', u'em', u'problem']
# [u'li', u'b', u'de', u'm', u'problem']
#
#
# [u'nick', u'c', u'l', u'egg']
# [u'nick', u'cleg', u'g']
#
#
# [u'c', u'l', u'u', u'el', u'es']
# [u'clue', u'l', u'es']
#
#
# [u'li', u'b', u'd', u'em', u'problem']
# [u'li', u'b', u'de', u'm', u'problem']
#
#
# [u'm', u'p', u'ona', u'train']
# [u'm', u'pon', u'at', u'rain']
#
#
# [u'election', u'de', u'bat']
# [u'election', u'deb', u'at']
#
#
# [u'ask', u'ni', u'gel', u'fa', u'rage']
# [u'ask', u'nig', u'elf', u'ara', u'ge']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u's', u'cotland']
# [u'scot', u'land']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'j', u'u', u't', u'ayin']
# [u'just', u'say', u'in']
#
#
# [u'stum', u'b', u'legate']
# [u'stumble', u'gate']
#
#
# [u'e', u'd', u'mil', u'li', u'band']
# [u'e', u'd', u'mill', u'iba', u'n', u'd']
#
#
# [u'mil', u'li', u'band']
# [u'mill', u'iba', u'n', u'd']
#
#
# [u'scot', u'ti', u'sh', u'labour']
# [u'scot', u'ti', u'h', u'labour']
#
#
# [u'ho', u'v', u'eh', u'u', u'sting']
# [u'hove', u'husting', u's']
#
#
# [u'justice', u'f', u'o', u'rab', u'used', u'child']
# [u'justice', u'forum', u'bus', u'e', u'd', u'child']
#
#
# [u'ni', u'gel', u'fa', u'rage']
# [u'nig', u'elf', u'ara', u'ge']
#
#
# [u'j', u'i', u'ha', u'di', u'j', u'oh', u'n']
# [u'jihad', u'i', u'jo', u'h', u'n']
#
#
# [u'j', u'i', u'ha', u'di', u'bride']
# [u'jihad', u'i', u'bride']
#
#
# [u'blind', u'side']
# [u'blind', u'ide']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'h', u'or', u'rib', u'leman']
# [u'horrible', u'man']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']
#
#
# [u'general', u'election']
# [u'generale', u'lection']
#
#
# [u'f', u'r', u'en', u'c', u'h', u'gate']
# [u'f', u're', u'n', u'c', u'h', u'gate']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'con', u'g', u'rat']
# [u'con', u'grat', u's']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u's', u'tal', u'ber', u't']
# [u'st', u'albe', u'r', u't']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'or', u'g', u'anise', u'd']
# [u'organ', u'is', u'e', u'd']
#
#
# [u'v', u'o', u't', u'eu', u'kip']
# [u'vote', u'u', u'kip']
#
#
# [u'taking', u'job', u'off', u'b', u'r', u'i', u'ti', u'sh', u'people']
# [u'taking', u'job', u'off', u'brit', u'is', u'h', u'people']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u's', u'cotland']
# [u'scot', u'land']
#
#
# [u's', u'inn', u'fe', u'in']
# [u'sin', u'n', u'fei', u'n']
#
#
# [u'mar', u'ga', u'ret', u'hod', u'ge']
# [u'mar', u'gare', u'tho', u'd', u'ge']
#
#
# [u'scot', u'ti', u'sh', u'labour']
# [u'scot', u'ti', u'h', u'labour']
#
#
# [u'ask', u'fa', u'rage']
# [u'ask', u'far', u'age']
#
#
# [u'liar', u'liar', u'pant', u'son', u'fire']
# [u'liar', u'liar', u'pant', u'on', u'fire']
#
#
# [u'oh', u'b', u'r', u'otherwhere', u'art', u'thou']
# [u'oh', u'brother', u'where', u'art', u'thou']
#
#
# [u's', u'to', u'pu', u'kip']
# [u'stop', u'u', u'kip']
#
#
# [u'we', u'are', u'all', u'do', u'o', u'me', u'd']
# [u'wear', u'ea', u'l', u'l', u'doom', u'e', u'd']
#
#
# [u'ask', u'fa', u'rage']
# [u'ask', u'far', u'age']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'v', u'o', u't', u'eu', u'kip']
# [u'vote', u'u', u'kip']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']
#
#
# [u's', u'cotland']
# [u'scot', u'land']
#
#
# [u'ni', u'gel', u'fa', u'rage']
# [u'nig', u'elf', u'ara', u'ge']
#
#
# [u'ni', u'gel', u'fa', u'rage']
# [u'nig', u'elf', u'ara', u'ge']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'c', u'l', u'egger']
# [u'cleg', u'gers']
#
#
# [u's', u'inn', u'fe', u'in']
# [u'sin', u'n', u'fei', u'n']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'h', u'or', u'rib', u'leman']
# [u'horrible', u'man']
#
#
# [u'f', u'racking']
# [u'frack', u'ing']
#
#
# [u'stum', u'b', u'legate']
# [u'stumble', u'gate']
#
#
# [u'ask', u'ni', u'gel', u'fa', u'rage']
# [u'ask', u'nig', u'elf', u'ara', u'ge']
#
#
# [u'general', u'election']
# [u'generale', u'lection']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']
#
#
# [u'voting', u'system', u'turnoff']
# [u'voting', u'y', u'te', u'm', u'turnoff']
#
#
# [u'poor', u'show']
# [u'poor', u'how']
#
#
# [u's', u'adman', u'ona', u'train']
# [u'sad', u'mano', u'natr', u'ai', u'n']
#
#
# [u'social', u'security']
# [u'social', u'e', u'cur', u'it', u'y']
#
#
# [u'ask', u'ni', u'gel', u'fa', u'rage']
# [u'ask', u'nig', u'elf', u'ara', u'ge']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'poor', u'show']
# [u'poor', u'how']
#
#
# [u'b', u'log', u'p', u'or', u'n', u'star']
# [u'blo', u'g', u'po', u'r', u'n', u'tar']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'ask', u'ni', u'gel', u'fa', u'rage']
# [u'ask', u'nig', u'elf', u'ara', u'ge']
#
#
# [u'general', u'election']
# [u'generale', u'lection']
#
#
# [u'sherlock', u'ho', u'l', u'me', u'incarnate']
# [u'sherlock', u'holm', u'e', u'incarnate']
#
#
# [u'ask', u'ni', u'gel', u'fa', u'rage']
# [u'ask', u'nig', u'elf', u'ara', u'ge']
#
#
# [u'n', u'om', u'n', u'ey', u'left']
# [u'no', u'm', u'ne', u'y', u'left']
#
#
# [u'get', u'to', u'the', u'point']
# [u'get', u'tot', u'hep', u'oint']
#
#
# [u'poor', u'show']
# [u'poor', u'how']
#
#
# [u'just', u'no', u'tup', u'toit']
# [u'just', u'not', u'up', u'toit']
#
#
# [u'de', u'f', u'f', u'o', u'not', u'p', u'c']
# [u'de', u'f', u'fono', u't', u'p', u'c']
#
#
# [u's', u'cotland']
# [u'scot', u'land']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'general', u'election']
# [u'generale', u'lection']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'general', u'election']
# [u'generale', u'lection']
#
#
# [u'v', u'e', u'ne', u'z', u'u', u'e', u'la']
# [u'v', u'en', u'e', u'z', u'u', u'el', u'a']
#
#
# [u'no', u'hit', u'sherlock']
# [u'no', u'hit', u'herl', u'ock']
#
#
# [u'v', u'e', u'ne', u'z', u'u', u'e', u'la']
# [u'v', u'en', u'e', u'z', u'u', u'el', u'a']
#
#
# [u'even', u'worse', u'than', u'kay', u'bur', u'ley']
# [u'even', u'worset', u'hank', u'ay', u'burl', u'ey']
#
#
# [u'd', u'ea', u'thof', u'labour']
# [u'death', u'of', u'labour']
#
#
# [u'too', u'close', u'to', u'call']
# [u'too', u'closet', u'o', u'call']
#
#
# [u'stum', u'b', u'legate']
# [u'stumble', u'gate']
#
#
# [u'q', u'f', u'era', u'news']
# [u'q', u'fe', u'rane', u'w']
#
#
# [u'ask', u'ni', u'cola', u'sturgeon']
# [u'ask', u'ni', u'cola', u'tur', u'geo', u'n']
#
#
# [u'ask', u'ni', u'gel', u'fa', u'rage']
# [u'ask', u'nig', u'elf', u'ara', u'ge']
#
#
# [u'm', u'anon', u'the', u'left']
# [u'mano', u'nth', u'el', u'eft']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'no', u'more', u'lie']
# [u'no', u'morel', u'y']
#
#
# [u'no', u'more', u'lie']
# [u'no', u'morel', u'y']
#
#
# [u'tea', u'party']
# [u'teap', u'arty']
#
#
# [u'unite', u'right']
# [u'uniter', u'i', u'g', u'h', u't']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'even', u'worse', u'than', u'kay', u'bur', u'ley']
# [u'even', u'worset', u'hank', u'ay', u'burl', u'ey']
#
#
# [u'no', u'more', u'lie']
# [u'no', u'morel', u'y']
#
#
# [u's', u'cotland']
# [u'scot', u'land']
#
#
# [u'like', u'you', u'dont', u'even', u'wan', u'tit']
# [u'like', u'youd', u'on', u'te', u'v', u'en', u'want', u'it']
#
#
# [u'the', u'real', u'no', u'escape']
# [u'there', u'is', u'no', u'cape']
#
#
# [u'even', u'worse', u'than', u'kay', u'bur', u'ley']
# [u'even', u'worset', u'hank', u'ay', u'burl', u'ey']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'al', u'li', u'nit', u'together']
# [u'all', u'in', u'it', u'together']
#
#
# [u'v', u'o', u't', u'eu', u'kip']
# [u'vote', u'u', u'kip']
#
#
# [u'jo', u'gon', u'j', u'i', u'm']
# [u'jog', u'on', u'j', u'i', u'm']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'stum', u'b', u'legate']
# [u'stumble', u'gate']
#
#
# [u'stum', u'b', u'legate']
# [u'stumble', u'gate']
#
#
# [u'no', u'more', u'lie']
# [u'no', u'morel', u'y']
#
#
# [u'general', u'election']
# [u'generale', u'lection']
#
#
# [u'ask', u'fa', u'rage']
# [u'ask', u'far', u'age']
#
#
# [u'n', u'otic', u'i', u'a']
# [u'not', u'i', u'c', u'i', u'a']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'b', u'i', u'ase', u'd', u'b', u'b', u'c']
# [u'bias', u'e', u'd', u'b', u'b', u'c']
#
#
# [u'c', u'h', u'ama', u'lie', u're']
# [u'chamal', u'ie', u're']
#
#
# [u'c', u'h', u'ama', u'lie', u're']
# [u'chamal', u'ie', u're']
#
#
# [u'd', u'avid', u'nag', u'hi']
# [u'da', u'v', u'id', u'nag', u'hi']
#
#
# [u'b', u'i', u'ase', u'd', u'b', u'b', u'c']
# [u'bias', u'e', u'd', u'b', u'b', u'c']
#
#
# [u'mi', u'li', u'band']
# [u'mil', u'iba', u'n', u'd']
#
#
# [u'social', u'security']
# [u'social', u'e', u'cur', u'it', u'y']
#
#
# [u'b', u'i', u'ase', u'd', u'b', u'b', u'c']
# [u'bias', u'e', u'd', u'b', u'b', u'c']
#
#
# [u'b', u'i', u'ase', u'd', u'b', u'b', u'c']
# [u'bias', u'e', u'd', u'b', u'b', u'c']
#
#
# [u'mi', u'li', u'fandom']
# [u'mil', u'if', u'and', u'om']
#
#
# [u'can', u'nab', u'is']
# [u'canna', u'b', u'is']
#
#
# [u'l', u'lan', u'el', u'li', u'h', u'u', u'sting']
# [u'l', u'lane', u'l', u'li', u'husting', u's']

# %%
"""Select the best one among reverse and forwad"""
improvement_forward = 0
improvement_reverse = 0
def Score(arr):
    sum_length_square = 0
    for word in arr:
        sum_length_square += len(word)**2
    return (sum_length_square*1.0)**(1/float(len(arr)))

# print(Score([u'a', u'th', u'aba', u'ca']))

for index,value in enumerate(result2):
#     print(hashtags[index])
#     if result2[index] == result[index]:
#         print(result2[index])
#         print('\r\n')
#     else:
#         result2_1char = [ele for ele in result2[index] if len(ele)==1]
        
#         print(result2[index])
#         print(Score(result2[index]))
#         print(result[index])
#         print(Score(result[index]))
#         print('\r\n')
    improvement_reverse += max(Score(result[index]),Score(result2[index]))/Score(result[index])-1
    improvement_forward += max(Score(result[index]),Score(result2[index]))/Score(result2[index])-1
#     Score_B += max(Score(result[index]),Score(result2[index]))
        
# improve_reverse = Score_B*1.0/Score_R*1.0 - 1

# improve_forward = Score_B*1.0/Score_F*1.0 - 1

print('Improved Reverse:'+ str(improvement_reverse*100/len(result))+'%')
print('Improved Forward:'+ str(improvement_forward*100/len(result))+'%')
# Out:
# Improved Reverse:6.19623508147%
# Improved Forward:4.33500110884%

# %% [markdown]
# ## Text classification (Not Optional)

# %% [markdown]
# <b>Instructions</b>: The twitter_sample corpus has two subcorpora corresponding to positive and negative tweets. You can access already tokenised versions using the <i> tokenized </i> method, as given in the code sample below. Iterate through these two corpora and build training, development, and test sets for use with Scikit-learn. You should exclude stopwords (from the built-in NLTK list) and tokens with non-alphabetic characters (this is very important you do this because emoticons were used to build the corpus, if you don't remove them performance will be artificially high). You should randomly split each subcorpus, using 80% of the tweets for training, 10% for development, and 10% for testing; make sure you do this <b>before</b> combining the tweets from the positive/negative subcorpora, so that the sets are <i>stratified</i>, i.e. the exact ratio of positive and negative tweets is preserved across the three sets. (1.0)

# %%
import numpy as np
positive_tweets = nltk.corpus.twitter_samples.tokenized("positive_tweets.json")
negative_tweets = nltk.corpus.twitter_samples.tokenized("negative_tweets.json")

np.random.shuffle(positive_tweets)
np.random.shuffle(negative_tweets)

train_positive = positive_tweets[:int(len(positive_tweets)*0.8)]
train_negative = negative_tweets[:int(len(negative_tweets)*0.8)]

dev_positive = positive_tweets[int(len(positive_tweets)*0.8):int(len(positive_tweets)*0.9)]
dev_negative = negative_tweets[int(len(negative_tweets)*0.8):int(len(negative_tweets)*0.9)]

test_positive = positive_tweets[int(len(positive_tweets)*0.9):]
test_negative = negative_tweets[int(len(negative_tweets)*0.9):]


from nltk.corpus import stopwords

stopwords = set(stopwords.words('english'))

from sklearn.feature_extraction import DictVectorizer

def get_BOW_lowered_no_stopwords(text):
    BOW = {}
    for word in text:
        word = word.lower()
        if word not in stopwords and len(re.findall(r"[^a-z]", word))== 0:
            BOW[word] = BOW.get(word,0) + 1
    return BOW

def prepare_data(datafile,feature_extractor):
    feature_matrix = []
    classifications = []
    for tweet in datafile:
        feature_dict = feature_extractor(tweet)   
        feature_matrix.append(feature_dict)
    vectorizer = DictVectorizer()
    dataset = vectorizer.fit_transform(feature_matrix)
    return dataset,vectorizer

def fit_data(datafile,feature_extractor, vectorizer):
    feature_matrix = []
    classifications = []
    for tweet in datafile:
        feature_dict = feature_extractor(tweet)   
        feature_matrix.append(feature_dict)
    dataset = vectorizer.transform(feature_matrix)
    return dataset

dataset, vectorizer = prepare_data(np.concatenate((train_positive,train_negative)), get_BOW_lowered_no_stopwords)
# print(dataset[1])
# dataset._shape

vectorized_dev = fit_data(np.concatenate((dev_positive,dev_negative)), get_BOW_lowered_no_stopwords, vectorizer)

vectorized_test = fit_data(np.concatenate((test_positive,test_negative)), get_BOW_lowered_no_stopwords, vectorizer)


train_X = dataset
train_y = np.concatenate((np.zeros(len(train_positive)),np.ones(len(train_negative))))

from scipy.sparse import coo_matrix
train_X_sparse = coo_matrix(train_X)

from sklearn.utils import shuffle
train_X, train_X_sparse, train_y = shuffle(train_X, train_X_sparse, train_y, random_state=0)

# print(vectorized_dev_positive.shape)

from sklearn.feature_extraction.text import TfidfTransformer

transformer = TfidfTransformer(smooth_idf=False,norm=None)

train_X = transformer.fit_transform(train_X)

dev_X = vectorized_dev
dev_y = np.concatenate((np.zeros(len(dev_positive)),np.ones(len(dev_negative))))
dev_X_sparse = coo_matrix(dev_X)
dev_X, train_X_sparse, dev_y = shuffle(dev_X, dev_X_sparse, dev_y, random_state=0)
dev_X = transformer.transform(dev_X)

test_X = vectorized_test
test_y = np.concatenate((np.zeros(len(test_positive)),np.ones(len(test_negative))))
test_X_sparse = coo_matrix(test_X)
test_X, test_X_sparse, test_y = shuffle(test_X, test_X_sparse, test_y, random_state=0)
test_X = transformer.transform(test_X)

# %% [markdown]
# <b>Instructions</b>: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation (hyper)parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do <b>not</b> use crossvalidation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the accuracy with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output. (1.0)

# %%
# %matplotlib inline
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

alpha_list = []
score_list = []

for i in range(1,100):
    alpha = i*0.1
    alpha_list.append(alpha)
    nb_cls = MultinomialNB(alpha = alpha)
    nb_cls.fit(dev_X, dev_y)
    f1 = nb_cls.score(dev_X, dev_y)
    score_list.append(f1)

plt.xlabel('Alpha')
plt.ylabel('F1-Score')
plt.title('MultinomialNB Parameter Tuning: Alpha')
plt.plot(alpha_list,score_list,'b-')
plt.show()

optimal_alpha = alpha_list[np.argmax(np.array(score_list))]
print('Optimal value of alpha:'+str(optimal_alpha))

C = [0.001, 0.01, 0.1, 1, 10, 100, 1000]
score_list = []
for c in C:
    nb_cls = LogisticRegression(C = c)
    nb_cls.fit(train_X, train_y)
    f1 = nb_cls.score(dev_X, dev_y)
    score_list.append(f1)

    
    
plt.xlabel('C')
plt.ylabel('F1-Score')
plt.title('LogisticRegression Parameter Tuning: C, Penalty=L2')
plt.plot(C,score_list,'b-')
plt.show()

score_list_l1 = []
for c in C:
    nb_cls = LogisticRegression(C = c,penalty = 'l1')
    nb_cls.fit(train_X, train_y)
    f1 = nb_cls.score(dev_X, dev_y)
    score_list_l1.append(f1)
plt.xlabel('C')
plt.ylabel('F1-Score')
plt.title('LogisticRegression Parameter Tuning: C, Penalty=L1')
plt.plot(C,score_list_l1,'b-')
plt.show()

optimal_c = C[np.argmax(np.array(score_list))]
optimal_penalty = 'l2'
if(np.max(np.array(score_list))<np.max(np.array(score_list_l1))):
    optimal_c = C[np.argmax(np.array(score_list_l1))]
    optimal_penalty = 'l1'
print('Optimal value of C and Penalty:'+str(optimal_c)+' '+str(optimal_penalty))
# Out:
# Optimal value of alpha:0.1
# Optimal value of C and Penalty:0.1 l2

# %% [markdown]
# <b>Instructions</b>: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both accuracy and macroaveraged f-score for each classifier. Be sure to label your output. (0.5)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

nb_cls = MultinomialNB(alpha = optimal_alpha)

nb_cls.fit(train_X, train_y)
y_pred = nb_cls.predict(test_X)

target_names = ['positive','negative']
print('MultinomialNB Classification Report:\r\n')
print(classification_report(test_y,y_pred, target_names=target_names))
print('Accuracy: '+str(accuracy_score(test_y,y_pred)))

lr_cls = LogisticRegression(C = optimal_c, penalty = optimal_penalty)
lr_cls.fit(train_X, train_y)
y_pred = lr_cls.predict(test_X)
print('-------------------------------------------------------------')
print('-------------------------------------------------------------')
print('\r\n\r\nLogisticRegression Classification Report:\r\n')
print(classification_report(test_y,y_pred, target_names=target_names))
print('Accuracy: '+str(accuracy_score(test_y,y_pred)))
# Out:
# MultinomialNB Classification Report:
#
#              precision    recall  f1-score   support
#
#    positive       0.69      0.72      0.71       500
#    negative       0.71      0.68      0.69       500
#
# avg / total       0.70      0.70      0.70      1000
#
# Accuracy: 0.701
# -------------------------------------------------------------
# -------------------------------------------------------------
#
#
# LogisticRegression Classification Report:
#
#              precision    recall  f1-score   support
#
#    positive       0.75      0.69      0.72       500
#    negative       0.72      0.77      0.74       500
#
# avg / total       0.74      0.73      0.73      1000
#
# Accuracy: 0.734
